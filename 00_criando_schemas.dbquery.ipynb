-- %%
-- 1. Cria o Catálogo principal do projeto
CREATE CATALOG IF NOT EXISTS olist_portfolio;

-- 2. Define o catálogo como o atual para os próximos comandos
USE CATALOG olist_portfolio;

-- 3. Cria as 3 camadas da Arquitetura Medalhão
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

-- 4. Cria o Volume para armazenar os arquivos CSV brutos
CREATE VOLUME bronze.raw_data;
